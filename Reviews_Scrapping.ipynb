# %%
# !apt-get update 
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url = "https://www.amazon.com/Xiaomi-Band-Wristband-Magnetic-Bluetooth/product-reviews/B089NS9JW2/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber="
comments = []
for i in range(150):
  driver.get(url + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data1 = pd.DataFrame({'Reviews': comments})
input_data1
# Out:
#                                                 Reviews
# 0       TLDR: After owning a $150 FitBit and a $35 L...
# 1       It's just mandarin, english, russian and spa...
# 2       I’m a Xiaomi fan so I may be a little lenien...
# 3       Love it so much!I mainly just need something...
# 4       I paired this with my iPhone, my S7 and my M...
# ...                                                 ...
# 1495    The Mi Fit offers great value for money but ...
# 1496    Sono molto soddisfatto dell'ordine che ho ef...
# 1497    Vengo de la miband 2 y el salto ha sido espe...
# 1498    Braciale molto confortevole. É un po' lento ...
# 1499    Preis-Leistung Top.Kritikpunkte:Display alti...
#
# [1500 rows x 1 columns]

# %%
input_data1.to_csv('xiaomi.csv', index=False)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url_2 = "https://www.amazon.com/Fitbit-Fitness-Activity-Tracking-Included/product-reviews/B084CQ41M2/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber"
comments = []
for i in range(100):
  driver.get(url_2 + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data_2 = pd.DataFrame({'Reviews': comments})
input_data_2
# Out:
#                                                Reviews
# 0      Got this after my charge 2 died and wow is i...
# 1      I won't be like everyone who gives a bad rev...
# 2      Fitbit's App:Let me start by saying, the Fit...
# 3      I finally received my Fitbit and unfortunate...
# 4      So just like another review on here ... my f...
# ..                                                 ...
# 995    So I'll preface my review by saying this is ...
# 996    This product worked as expected out the box....
# 997    Being such a fan of the value that leftover ...
# 998    I have been wearing a Fitbit for several yea...
# 999    I've worn a Fitbit on my wrist for several y...
#
# [1000 rows x 1 columns]

# %%
input_data_2.to_csv('fitbit.csv', index=False)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url_3 = "https://www.amazon.com/Fitbit-Inspire-Fitness-Tracker-included/product-reviews/B07MM5W7Q8/ref=cm_cr_arp_d_paging_btm_next_2?ref_=fspcr_pl_ar_4_5393958011&pageNumber="
comments = []
for i in range(100):
  driver.get(url_3 + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data_3 = pd.DataFrame({'Reviews': comments})
input_data_3
# Out:
#                                                Reviews
# 0      I purchased this item from Target. I’ve owne...
# 1      i went to go buy the Charge 3, at Walmart- a...
# 2      I’ve been using Fitbit for 4 years. This is ...
# 3      I love the functions and pretty everything a...
# 4      it looks great! but it counts steps while yo...
# ..                                                 ...
# 995    It's comfortable and cute. I love the differ...
# 996    I've been using my FitBit Inspire HR for abo...
# 997    I hate this FitBit. The battery doesn’t even...
# 998    UpdateUnder the 1 year warranty I was able t...
# 999    The Inspire HR worked well for 4 months and ...
#
# [1000 rows x 1 columns]

# %%
input_data_3.to_csv('fitbit_inspire.csv', index=False)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url_4 = "https://www.amazon.com/Fitbit-Inspire-Fitness-Tracker-included/product-reviews/B07MM5WMPF/ref=cm_cr_arp_d_paging_btm_next_2?ref_=fspcr_pl_ar_5_5393958011&pageNumber="
comments = []
for i in range(100):
  driver.get(url_4 + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data_4 = pd.DataFrame({'Reviews': comments})
input_data_4
# Out:
#                                                Reviews
# 0      I read a decent amount of the reviews before...
# 1      I've owned the Fitbit Alta, Alta HR, and Bla...
# 2      Absolutely love the look, feel and usefulnes...
# 3      Edited to add: I've now tried to sync this p...
# 4      My fault for not reading carefully enough, b...
# ..                                                 ...
# 995    I like it overall but sometimes just the mov...
# 996                                            Awesome
# 997                   Keeps me on track with my goals!
# 998                                              is ok
# 999    I bought this Fitbit so I could track my swi...
#
# [1000 rows x 1 columns]

# %%
input_data_4.to_csv('fitbit_inspire_2.csv', index=False)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url_5 = "https://www.amazon.com/Fitness-Tracker-Activity-Pedometer-Bracelet/product-reviews/B0851656J6/ref=cm_cr_arp_d_paging_btm_next_2?ref_=fspcr_pl_ar_6_5393958011&pageNumber="
comments = []
for i in range(100):
  driver.get(url_5 + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data_5 = pd.DataFrame({'Reviews': comments})
input_data_5
# Out:
#                                                Reviews
# 0      I'll start with the bad, because I know that...
# 1      I love this device.  I bought mainly for the...
# 2      I first bought this multi-function watch/fit...
# 3      Huawei Honor band 5iOS 13.6 Charged using su...
# 4      Received it a couple days ago. Wanting to wa...
# ..                                                 ...
# 995    E' molto bello e con una interfaccia facile ...
# 996    Eigentlich würde ich diesem Band 2 oder 3 St...
# 997    È quasi una settimana ke lo uso e sono soddi...
# 998    unica cosa che non mi piace e che schermo tr...
# 999    Ho acquistato questa smartband in sostituzio...
#
# [1000 rows x 1 columns]

# %%
input_data_5.to_csv('pedometer-bracelet.csv', index=False)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url_6 = "https://www.amazon.com/YAMAY-Fitness-Waterproof-Smartwatch-Compatible/product-reviews/B082LQLWGX/ref=cm_cr_arp_d_paging_btm_next_2?ref_=fspcr_pl_ar_9_5393958011&pageNumber="
comments = []
for i in range(100):
  driver.get(url_6 + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data_6 = pd.DataFrame({'Reviews': comments})
input_data_6
# Out:
#                                                Reviews
# 0      I love gadgets and am always looking for new...
# 1      I've own other smart watches/trackers in the...
# 2      Your browser does not support HTML5 video.  ...
# 3      I originally wanted a Apple Watch but didn't...
# 4      I have been using this watch everyday for mo...
# ..                                                 ...
# 995    I bought this watch to track steps. I though...
# 996    Bought this watch as a Christmas present for...
# 997    Had a Fitbit Versa2 which quit after only 2 ...
# 998    I would like to start off by saying this isn...
# 999    I loved this watch, it’s durable and not che...
#
# [1000 rows x 1 columns]

# %%
input_data_6.to_csv('yamay.csv', index=False)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url_7 = "https://www.amazon.com/LETSCOM-Resistant-Activity-Tracking-Pedometer/product-reviews/B07WZQP556/ref=cm_cr_arp_d_paging_btm_next_2?ref_=fspcr_pl_ar_10_5393958011&pageNumber="
comments = []
for i in range(100):
  driver.get(url_7 + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data_7 = pd.DataFrame({'Reviews': comments})
input_data_7
# Out:
#                                                Reviews
# 0      This smart watch is wonderful! Great price a...
# 1      This L version is far superior to the older ...
# 2      Your browser does not support HTML5 video.  ...
# 3      The price is great for product I recieved!! ...
# 4      We bought 2 of the fitness trackers for our ...
# ..                                                 ...
# 995    This watch does more than I expected, so in ...
# 996    So far it has been a great product! It is ve...
# 997    app is trash. Accessing the features, which ...
# 998    I absolutely love everything about this! Bou...
# 999    Watch is attractive and comfortable to wear....
#
# [1000 rows x 1 columns]

# %%
input_data_7.to_csv('letscom.csv', index=False)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url_8 = "https://www.amazon.com/Huawei-Activity-Bangle-PRO-Black/product-reviews/B074FZST75/ref=cm_cr_arp_d_paging_btm_next_2?ref_=fspcr_pl_ar_11_5393958011&pageNumber="
comments = []
for i in range(100):
  driver.get(url_8 + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data_8 = pd.DataFrame({'Reviews': comments})
input_data_8
# Out:
#                                                Reviews
# 0      I know this watch is a couple years old now,...
# 1      Doesn't have many bells and whistles as othe...
# 2      I was very happy with this product when I fi...
# 3      I really enjoyed this product for the first ...
# 4      This is a good smart tracker watch with a qu...
# ..                                                 ...
# 995    Utilisation au quotidien, particulièrement p...
# 996    Not good ,strap comes away from body of watc...
# 997                                      Great product
# 998                                     Very satisfied
# 999                                          Very good
#
# [1000 rows x 1 columns]

# %%
input_data_8.to_csv('hauwei.csv', index=False)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url_9 = "https://www.amazon.com/BIGGERFIVE-Fitness-Activity-Pedometer-Waterproof/product-reviews/B08CXVCZJZ/ref=cm_cr_arp_d_paging_btm_next_2?ref_=fspcr_pl_ar_12_5393958011&pageNumber="
comments = []
for i in range(100):
  driver.get(url_9 + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data_9 = pd.DataFrame({'Reviews': comments})
input_data_9
# Out:
#                                                Reviews
# 0      My mom has a heart condition that makes her ...
# 1      We got the watch to set multiple alarms for ...
# 2      This is just like a A Fitbit for kids for a ...
# 3      The watch works as described, and fits a 5 y...
# 4      We purchased this tracker for my 8-year old ...
# ..                                                 ...
# 995                    Bien, pero no es rosa, es rojo.
# 996                                           Not bad.
# 997    Se lo compré a mi sobri y es súper majo, se ...
# 998    How do you "login"? Always says error. No em...
# 999    Super jolie montre ma fille de 10 ans adore ...
#
# [1000 rows x 1 columns]

# %%
input_data_9.to_csv('biggerfive.csv', index=False)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

driver = webdriver.Chrome('chromedriver',options=options)
url_10 = "https://www.amazon.com/Fitpolo-Trackers-Waterproof-Monitoring-Pedometer/product-reviews/B07Y4MGXC9/ref=cm_cr_arp_d_paging_btm_next_2?ref_=fspcr_pl_ar_15_5393958011&pageNumber="
comments = []
for i in range(60):
  driver.get(url_10 + str (i))
  time.sleep(4)
  page = BeautifulSoup(driver.page_source,'lxml')
  all_divs = page.findAll('div')
  for ele in all_divs:
    if(ele.get('id')):
      if('-review-card' in ele.get('id')):
        get_span_data = ele.find('span',{'data-hook':'review-body'}).text
        comments.append(get_span_data.replace('\n',''))
    next_button = driver.find_element_by_class_name("a-last")
    i = i + 1

input_data_10 = pd.DataFrame({'Reviews': comments})
input_data_10
# Out:
#                                                Reviews
# 0      If you’re looking for a basic fitness watch ...
# 1      I would like to address one issue before mov...
# 2      Your browser does not support HTML5 video.  ...
# 3      I purchased this for my sister-in-law for Ch...
# 4      I LOVE this watch!!! Its everything I wanted...
# ..                                                 ...
# 595    Très belle couleur et installation rapide.Se...
# 596                                 Bin sehr zufrieden
# 597     Produit arrivé intact. Bon produit, pas déçue.
# 598    Fonction idéale pour bien suivre des séances...
# 599    Top cette montre je la conseille pour le pri...
#
# [600 rows x 1 columns]

# %%
input_data_10.to_csv('fitpolo.csv', index=False)

# %%
frames = [input_data1, input_data_2, input_data_3, input_data_4, input_data_5, input_data_6, input_data_7, input_data_8, input_data_9, input_data_10]
input_data = pd.concat(frames)

# %%
input_data.to_csv('data.csv', index=False)
